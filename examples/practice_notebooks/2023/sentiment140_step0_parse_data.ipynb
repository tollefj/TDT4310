# %% [markdown]
# ```
# 0 - the polarity of the tweet (0 = negative, 2 = neutral, 4 = positive)
# 1 - the id of the tweet (2087)
# 2 - the date of the tweet (Sat May 16 23:58:44 UTC 2009)
# 3 - the query (lyx). If there is no query, then this value is NO_QUERY.
# 4 - the user that tweeted (robotickilldozr)
# 5 - the text of the tweet (Lyx is cool)
# ```

# %% [markdown]
# ## Downloading data
# There is a script located under data/sentiment140/download.sh

# %%
# the huggingface datasets library will be helpful for many future projects!
# %pip install datasets
# Out:
# Requirement already satisfied: datasets in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (2.16.1)
# Requirement already satisfied: filelock in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (1.26.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (0.20.2)
# Requirement already satisfied: packaging in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from huggingface-hub>=0.19.4->datasets) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import load_dataset

dataset = load_dataset("sentiment140")  # requires ~120MB

# %%
train_df = dataset["train"].to_pandas()
train_df
# Out:
#                                                       text  \
# 0        @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1        is upset that he can't update his Facebook by ...
# 2        @Kenichan I dived many times for the ball. Man...
# 3          my whole body feels itchy and like its on fire
# 4        @nationwideclass no, it's not behaving at all....
# ...                                                    ...
# 1599995  Just woke up. Having no school is the best fee...
# 1599996  TheWDB.com - Very cool to hear old Walt interv...
# 1599997  Are you ready for your MoJo Makeover? Ask me f...
# 1599998  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999  happy #charitytuesday @theNSPCC @SparksCharity...
#
#                                  date             user  sentiment     query
# 0        Mon Apr 06 22:19:45 PDT 2009  _TheSpecialOne_          0  NO_QUERY
# 1        Mon Apr 06 22:19:49 PDT 2009    scotthamilton          0  NO_QUERY
# 2        Mon Apr 06 22:19:53 PDT 2009         mattycus          0  NO_QUERY
# 3        Mon Apr 06 22:19:57 PDT 2009          ElleCTF          0  NO_QUERY
# 4        Mon Apr 06 22:19:57 PDT 2009           Karoli          0  NO_QUERY
# ...                               ...              ...        ...       ...
# 1599995  Tue Jun 16 08:40:49 PDT 2009  AmandaMarie1028          4  NO_QUERY
# 1599996  Tue Jun 16 08:40:49 PDT 2009      TheWDBoards          4  NO_QUERY
# 1599997  Tue Jun 16 08:40:49 PDT 2009           bpbabe          4  NO_QUERY
# 1599998  Tue Jun 16 08:40:49 PDT 2009     tinydiamondz          4  NO_QUERY
# 1599999  Tue Jun 16 08:40:50 PDT 2009   RyanTrevMorris          4  NO_QUERY
#
# [1600000 rows x 5 columns]

# %%
# we're only interested in sentiment and text
train_df = train_df[["sentiment", "text"]]
train_df
# Out:
#          sentiment                                               text
# 0                0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                0  is upset that he can't update his Facebook by ...
# 2                0  @Kenichan I dived many times for the ball. Man...
# 3                0    my whole body feels itchy and like its on fire
# 4                0  @nationwideclass no, it's not behaving at all....
# ...            ...                                                ...
# 1599995          4  Just woke up. Having no school is the best fee...
# 1599996          4  TheWDB.com - Very cool to hear old Walt interv...
# 1599997          4  Are you ready for your MoJo Makeover? Ask me f...
# 1599998          4  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999          4  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1600000 rows x 2 columns]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
nltk.download('stopwords')
import re

STOP = stopwords.words("english")

twitter_words_to_filter = ["rt"]
def filter_single_letter(word):
    return len(word) > 1 or word == 'a' or word == 'i'

tt = TweetTokenizer()
def twitter_preprocessing(post):
    tokenized_post = tt.tokenize(post)
    pattern = re.compile(r"^[a-zA-Z\!\?\,\.\']+$")
    dot_pattern = re.compile(r"\.{2,}")
    url_matcher = re.compile(r"^[a-zA-Z]+\.[a-zA-Z]+$")
    tokens = [
        w.lower() for w in tokenized_post
        if pattern.match(w) and not dot_pattern.match(w)
        and w.lower() not in twitter_words_to_filter
        and filter_single_letter(w.lower())
        and not url_matcher.match(w.lower())
    ]
    return tokens
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/tollef/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# apply preprocessing to the tweets
# (depending on computational power)
# %pip install mapply
import mapply
mapply.init()
train_df["text"] = train_df.text.mapply(twitter_preprocessing, train_df["text"].tolist())
# Out:
# Requirement already satisfied: mapply in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (0.1.23)
# Requirement already satisfied: pathos>=0.3.1 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from mapply) (0.3.1)
# Requirement already satisfied: multiprocess in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from mapply) (0.70.15)
# Requirement already satisfied: psutil in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from mapply) (5.9.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from mapply) (4.66.1)
# Requirement already satisfied: ppft>=1.7.6.7 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from pathos>=0.3.1->mapply) (1.7.6.7)
# Requirement already satisfied: dill>=0.3.7 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from pathos>=0.3.1->mapply) (0.3.7)
# Requirement already satisfied: pox>=0.3.3 in /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages (from pathos>=0.3.1->mapply) (0.3.3)
# Note: you may need to restart the kernel to use updated packages.
# /Users/tollef/git/COURSES/TDT4310/.conda/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# 100%|██████████| 80/80 [00:13<00:00,  5.77it/s]
# /var/folders/0k/1bg63zt532nb9d86g5tk_6vh0000gn/T/ipykernel_34112/3619078282.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df["text"] = train_df.text.mapply(twitter_preprocessing, train_df["text"].tolist())

# %%
train_df
# Out:
#          sentiment                                               text
# 0                0  [awww, that's, a, bummer, you, shoulda, got, d...
# 1                0  [is, upset, that, he, can't, update, his, face...
# 2                0  [i, dived, many, times, for, the, ball, manage...
# 3                0  [my, whole, body, feels, itchy, and, like, its...
# 4                0  [no, it's, not, behaving, at, all, i'm, mad, w...
# ...            ...                                                ...
# 1599995          4  [just, woke, up, having, no, school, is, the, ...
# 1599996          4      [very, cool, to, hear, old, walt, interviews]
# 1599997          4  [are, you, ready, for, your, mojo, makeover, a...
# 1599998          4  [happy, birthday, to, my, boo, of, alll, time,...
# 1599999          4                                            [happy]
#
# [1600000 rows x 2 columns]

# %%
# filter out texts with less than 5 words:
train_df = train_df[train_df.text.map(len) > 5]

# %%
# add a column that is the text as a string:
train_df["text_str"] = train_df.text.map(lambda x: " ".join(x))
# Out:
# /var/folders/0k/1bg63zt532nb9d86g5tk_6vh0000gn/T/ipykernel_34112/1118835850.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df["text_str"] = train_df.text.map(lambda x: " ".join(x))

# %%
train_df = train_df.rename(columns={"text": "tokens", "text_str": "text"})

# %%
train_df
# Out:
#          sentiment                                             tokens  \
# 0                0  [awww, that's, a, bummer, you, shoulda, got, d...
# 1                0  [is, upset, that, he, can't, update, his, face...
# 2                0  [i, dived, many, times, for, the, ball, manage...
# 3                0  [my, whole, body, feels, itchy, and, like, its...
# 4                0  [no, it's, not, behaving, at, all, i'm, mad, w...
# ...            ...                                                ...
# 1599994          4  [yeah, that, does, work, better, than, just, w...
# 1599995          4  [just, woke, up, having, no, school, is, the, ...
# 1599996          4      [very, cool, to, hear, old, walt, interviews]
# 1599997          4  [are, you, ready, for, your, mojo, makeover, a...
# 1599998          4  [happy, birthday, to, my, boo, of, alll, time,...
#
#                                                       text
# 0        awww that's a bummer you shoulda got david car...
# 1        is upset that he can't update his facebook by ...
# 2        i dived many times for the ball managed to sav...
# 3           my whole body feels itchy and like its on fire
# 4        no it's not behaving at all i'm mad why am i h...
# ...                                                    ...
# 1599994  yeah that does work better than just waiting f...
# 1599995  just woke up having no school is the best feel...
# 1599996              very cool to hear old walt interviews
# 1599997  are you ready for your mojo makeover ask me fo...
# 1599998  happy birthday to my boo of alll time tupac am...
#
# [1305022 rows x 3 columns]

# %%
train_df.to_csv("sentiment140_train.csv", index=False)
